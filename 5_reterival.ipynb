# %%
# !pip install pinecone sentence-transformers ipykernel

# %%
import time
from pinecone import Pinecone, ServerlessSpec
from sentence_transformers import SentenceTransformer

print("=== INITIALIZING PINECONE CLOUD INDEX OVER API PROXY ===")

PINECONE_API_KEY = "pcsk_5cydku_Gg5MFPrKUeGzvWEya7B7PW9UanEtcAMMahQEBx6waSGmVyPWA4nJm5a9FVxYuiD"
pc = Pinecone(api_key=PINECONE_API_KEY)
index_name = "ey-index-061520261316"
index = pc.Index(index_name)

print(f"Connected to Pinecone Index: '{index_name}' successfully.")
# STEP 2: LOAD THE LOCAL EMBEDDING PIPELINE
print("Loading local semantic vector transformer...")
model = SentenceTransformer('all-MiniLM-L6-v2')
# Out:
# === INITIALIZING PINECONE CLOUD INDEX OVER API PROXY ===
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 10
#       8 pc = Pinecone(api_key=PINECONE_API_KEY)
#       9 index_name = "ey-index-061520261316"
# ---> 10 index = pc.Index(index_name=index_name)
#      12 print(f"Connected to Pinecone Index: '{index_name}' successfully.")
#      13 # STEP 2: LOAD THE LOCAL EMBEDDING PIPELINE
#
# File ~/anaconda3/lib/python3.13/site-packages/pinecone/_client.py:866, in Pinecone.Index(self, name, host, **kwargs)
#     864 pool_threads = kwargs.pop("pool_threads", None)
#     865 if kwargs:
# --> 866     raise TypeError(
#     867         f"Pinecone.Index() got unexpected keyword arguments: {sorted(kwargs)!r}"
#     868     )
#     869 from pinecone.index import Index as _Index
#     871 return cast(_Index, self.index(name=name, host=host, pool_threads=pool_threads))
#
# TypeError: Pinecone.Index() got unexpected keyword arguments: ['index_name']

# %%
# STEP 3: CONSTRUCT THE SEMANTIC QUERY
user_query = "Where do we store our data and how much space is allocated?"
print(f"\nUser Input Query:\n -> '{user_query}'")


# STEP 4: VECTORIZE THE QUESTION
print("Computing vector coordinates for the query...")
query_embedding = model.encode(user_query).tolist()
